# %%
floor_to_bottom = [
    (24.8, 0.15),
    (25.1, 0.2),
    (25.5, 0.1),
    (25.2, 0.12),
    (25.1, 0.18)
]

floor_to_top = [
    (49.8, 0.2),
    (50.1, 0.2),
    (50.5, 0.1),
    (49.99, 0.12),
    (49.9, 0.18)
]

pendulum_length_laser = [
    (22.257, 999),
    (22.259, 999),
    (22.257, 999),
    (22.256, 999),
    (22.257, 999)
]

pendulum_length_tape = [
    (22.258, 0.8),
    (22.268, 1),
    (22.257, 0.7),
    (22.249, 1),
    (22.255, 1)
]

diameter_ball_big = [
    (15, 0.05),
    (14.8, 0.1),
    (14.9, 0.15),
    (14.8, 0.2),
    (14.9, 0.1)
]

diameter_ball_medium = [
    (12, 0.05),
    (11.8, 0.1),
    (11.9, 0.15),
    (12, 0.2),
    (11.9, 0.1)
]

diameter_ball_small = [
    (10, 0.05),
    (9.9, 0.1),
    (9.8, 0.15),
    (9.9, 0.2),
    (9.9, 0.1)
]

slope_height = [
    (22.28, 0.05),
    (22.29, 0.2),
    (22.26, 0.04),
    (22.3, 0.05),
    (22.25, 0.05)
]

slope_length = [
    (89.61, 0.1),
    (89.5, 0.02),
    (89.4, 0.01),
    (89.65, 0.04),
    (89.51, 0.05)
]

slope_angle = [
    (75.9, 0.06),
    (76.1, 0.05),
    (75.8, 0.08),
    (75.9, 0.1)
    # other side
    (75.9, 0.06),
    (76.2, 0.05),
    (76.1, 0.08),
    (76.08, 0.1)
]

gate_1_length = [
    (8.48, 0.1),
    (8.4, 0.1),
    (8.45, 0.07),
    (8.45, 0.2),
    (8.5, 0.1)
]

gate_2_length = [
    (23.45, 0.1),
    (23.3, 0.1),
    (23.4, 0.07),
    (23.4, 0.2),
    (23.4, 0.1)
]

gate_3_length = [
    (38.6, 0.1),
    (38.5, 0.1),
    (38.5, 0.07),
    (38.6, 0.2),
    (38.6, 0.1)
]

gate_4_length = [
    (53.55, 0.1),
    (53.4, 0.1),
    (53.45, 0.07),
    (53.45, 0.2),
    (53.5, 0.1)
]

gate_5_length = [
    (69.2, 0.1),
    (69, 0.1),
    (69.1, 0.07),
    (69.1, 0.2),
    (69.2, 0.1)
]
